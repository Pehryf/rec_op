# %% [markdown]
# # Transformer

# %% [markdown]
# ## 1. Definition
#
# > Origin, category, key concepts.

# %% [markdown]
# ## 2. Formal Description
#
# > Mathematical formulation, objective function, variables.

# %% [markdown]
# ## 3. Architecture / Algorithm Steps
#
# > Detailed breakdown of the model architecture and inference procedure.

# %% [markdown]
# ## 4. Complexity Analysis
#
# > Time and space complexity.

# %% [markdown]
# ## 5. Strengths and Limitations

# %% [markdown]
# ## 6. Use Case Explanation
#
# > When and why to use this approach for combinatorial optimization.

# %% [markdown]
# ## 7. Implementation

# %%
# Implementation

# %% [markdown]
# ## 8. Demonstration
#
# > Small instance walkthrough.

# %%
# Demo on a small TSP instance

# %% [markdown]
# ## 9. Benchmark
#
# > TSP instances: n = 1, 10, 100, 10 000, 100 000
# >
# > Metrics: success rate, false positive rate, undetermined rate.

# %%
# Benchmark

# %% [markdown]
# ## 10. Experimental Analysis
#
# > Scalability, behavioral analysis, comparison with other models, limitations, improvement proposals.

# %% [markdown]
# ## 11. References
#
# - Kool et al., *Attention, Learn to Solve Routing Problems!* (2019)
