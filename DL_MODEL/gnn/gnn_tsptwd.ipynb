# %% [markdown]
# # TSPTW-D Benchmark
# Evaluates the trained **GNN** on the TSPTW-D problem.
#
# Objective:
#
# $$Z(\sigma) = 	au_{	ext{return}} + \sum_i \lambda_i \cdot \max(0,\, 	au_i - b_i)$$
#
# **Dynamic cost** $c_{ij}(t) = c_{ij}^{	ext{base}} \cdot (1 + \delta_{ij}(t))$
#
# **Next-day rule** — arrival $> b_i 	imes (1 + 5\%)$ postpones delivery to
# $	au_i \leftarrow H + a_i$ (next morning opening).

# %% [markdown]
# ## 1. Configuration & Model Loading

# %%
import os, sys, time
import torch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# ── Device selection ──────────────────────────────────────────────────────────
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
elif torch.backends.mps.is_available():
    DEVICE = torch.device('mps')
else:
    DEVICE = torch.device('cpu')

# ── Paths ─────────────────────────────────────────────────────────────────────
_HERE       = os.path.dirname(os.path.abspath('__file__'))
DATASET_DIR = os.path.join(_HERE, '..', '..', 'datasets')
FIGURES_DIR = Path(_HERE) / 'figures' / 'benchmark'
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

# ── User config ───────────────────────────────────────────────────────────────
SIZE     = 'medium'   # 'small' | 'medium' | 'large'
N_REPS   = 20        # timing repetitions per algorithm
LATE_TOL = 0.05      # 5 % tolerance before next-day rule applies

MODEL_PATH = os.path.join(_HERE, 'model', f'gnn_{SIZE}_tsptwd.pt')

print(f'Device : {DEVICE}')
print(f'Model  : {MODEL_PATH}')
print(f'Dataset: {DATASET_DIR}')

# %%
sys.path.insert(0, _HERE)
from model import TSPGNN, MODEL_SIZES

if not os.path.exists(MODEL_PATH):
    raise FileNotFoundError(f'{MODEL_PATH} not found — run train.py first.')

_ckpt     = torch.load(MODEL_PATH, map_location='cpu')
_node_dim = _ckpt['node_in.weight'].shape[1]
_edge_dim = _ckpt['edge_in.weight'].shape[1]

D, L  = MODEL_SIZES[SIZE]
model = TSPGNN(d=D, L=L, node_dim=_node_dim, edge_dim=_edge_dim)
model.load_state_dict(_ckpt)
model.to(DEVICE)
model.eval()

n_params = sum(p.numel() for p in model.parameters())
print(f'Loaded   : {SIZE}  ({n_params:,} parameters)')
print(f'node_dim : {_node_dim}   edge_dim: {_edge_dim}')
print(f'Device   : {next(model.parameters()).device}')

# %% [markdown]
# ## 2. Model Performance & Details

# %%
_loss_path = os.path.join(_HERE, 'model', 'losses.npy')
losses = np.load(_loss_path).tolist() if os.path.exists(_loss_path) else []

from data import (build_tsptwd_features, generate_time_windows,
                  generate_perturbations, optimal_tour_labels, greedy_decode)

# Probe instance for timing and visualisation
_coords_p = torch.rand(10, 2)
_tw_p, _svc_p = generate_time_windows(_coords_p, seed=0)
_perturbs_p   = generate_perturbations(10, total_time=_tw_p[:,1].max().item(), seed=0)
_nf_p, _ef_p  = build_tsptwd_features(_coords_p, _tw_p, _svc_p, _perturbs_p)
_nf_p = _nf_p.to(DEVICE); _ef_p = _ef_p.to(DEVICE)

# Warm-up + timing
with torch.no_grad():
    for _ in range(5):
        model(_nf_p, _ef_p)
_times = []
with torch.no_grad():
    for _ in range(50):
        if DEVICE.type == 'cuda':
            torch.cuda.synchronize()
        t0 = time.perf_counter()
        model(_nf_p, _ef_p)
        if DEVICE.type == 'cuda':
            torch.cuda.synchronize()
        _times.append((time.perf_counter() - t0) * 1e3)

print(f'Parameters : {n_params:,}')
print(f'Inference  : {np.mean(_times):.3f} ms  (±{np.std(_times):.3f})  on {DEVICE}, n=10')
if losses:
    print(f'Training   : {len(losses)} steps   best loss {min(losses):.4f}')

# ── Plots ──────────────────────────────────────────────────────────────────────
_y_true = optimal_tour_labels(_coords_p)
with torch.no_grad():
    _p_hat = model(_nf_p, _ef_p).cpu()

_ncols = 3 if losses else 2
fig, axes = plt.subplots(1, _ncols, figsize=(6 * _ncols, 4))
_ax = iter(axes)

if losses:
    ax = next(_ax)
    ax.plot(losses, color='steelblue', lw=1.2)
    ax.set_title('Training Loss (BCE)')
    ax.set_xlabel('Step'); ax.set_ylabel('Loss')
    ax.grid(True, alpha=0.3)

ax = next(_ax)
im = ax.imshow(_y_true.numpy(), cmap='Greens', vmin=0, vmax=1)
ax.set_title('Ground-truth edges $y_{ij}$')
ax.set_xlabel('City $j$'); ax.set_ylabel('City $i$')
plt.colorbar(im, ax=ax, fraction=0.046)

ax = next(_ax)
im = ax.imshow(_p_hat.numpy(), cmap='RdYlGn', vmin=0, vmax=1)
ax.set_title('Predicted probs $\hat{p}_{ij}$')
ax.set_xlabel('City $j$'); ax.set_ylabel('City $i$')
plt.colorbar(im, ax=ax, fraction=0.046)

plt.tight_layout()
plt.savefig(FIGURES_DIR / 'model_detail.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Benchmark — TSPTW-D
#
# Datasets from `datasets/tsptwd_n{n}.json` (generated by `datasetsgenerator.ipynb`).
# Defaults: **n = 10** and **n = 500**. All available sizes run in the last cell.
#
# | Column | Description |
# |--------|-------------|
# | `travel` | Return time to depot $	au_{	ext{return}}$ (minutes) |
# | `penalty` | Soft TW violation $\sum \lambda_i \max(0, 	au_i - b_i)$ (minutes) |
# | `next_day` | Cities pushed to next-day delivery |
# | `obj` | $Z(\sigma) = 	ext{travel} + 	ext{penalty}$ (minutes) |
# | `ms` | Mean inference time over 20 runs |

# %%
# ══════════════════════════════════════════════════════════════════════════════
# Benchmark helpers — run this cell before any benchmark cell below
# ══════════════════════════════════════════════════════════════════════════════
import glob as _glob
import re as _re
import json as _json
from data import build_tsptwd_features, greedy_decode

SCALE = 200.0  # normalised [0,1]² × 200 → minutes


# ── Dataset discovery ─────────────────────────────────────────────────────────
def discover_datasets(max_n=None):
    """Return sorted list of (n, path) for all tsptwd_n*.json files."""
    pattern = os.path.join(DATASET_DIR, 'tsptwd_n*.json')
    result = []
    for p in sorted(_glob.glob(pattern)):
        m = _re.search(r'tsptwd_n(\d+)\.json$', p)
        if m:
            n = int(m.group(1))
            if max_n is None or n <= max_n:
                result.append((n, p))
    return result

AVAILABLE = discover_datasets()


# ── Dataset loader ─────────────────────────────────────────────────────────────
def load_dataset(n):
    """Load datasets/tsptwd_n{n}.json → benchmark-ready dict (CPU tensors)."""
    path = os.path.join(DATASET_DIR, f'tsptwd_n{n}.json')
    with open(path, encoding='utf-8') as fh:
        d = _json.load(fh)
    scale   = float(d['meta']['scale'])
    horizon = float(d['meta'].get('horizon', scale))
    nodes   = [d['depot']] + d['clients']

    def _b(v):
        return float(v['b']) / scale if v['b'] is not None else horizon / scale

    coords   = torch.tensor([[v['x'], v['y']] for v in nodes], dtype=torch.float32)
    tw       = torch.tensor([[float(v['a']) / scale, _b(v)] for v in nodes], dtype=torch.float32)
    svc      = torch.tensor([float(v['service']) / scale for v in nodes], dtype=torch.float32)
    perturbs = [
        (int(p['arc'][0]), int(p['arc'][1]),
         float(p['t_start']) / scale, float(p['t_end']) / scale,
         float(p['alpha']))
        for p in d.get('perturbations', [])
    ]
    nf, ef = build_tsptwd_features(coords, tw, svc, perturbs)
    return {'n': len(nodes) - 1, 'coords': coords, 'tw': tw, 'svc': svc,
            'perturbs': perturbs, 'nf': nf, 'ef': ef}


# ── Multi-day TW core helper ──────────────────────────────────────────────────
def _tw_advance(t, a_i, b_i, horizon):
    """
    Apply multi-day time-window rules given current clock t.

    The window [a_i, b_i] repeats every horizon minutes.
    The relevant day is floor(t / horizon).

      t < a_i + day*H  → early arrival, wait (NOT a violation)
      t ≤ b_i + day*H  → within window, serve immediately
      t > b_i + day*H  → missed window → jump to next-day opening (violation)

    Returns (new_t, is_violation).
    """
    day   = int(t / horizon) if horizon > 0 else 0
    a_day = a_i + day * horizon
    b_day = b_i + day * horizon
    if t <= b_day:
        return max(t, a_day), False          # early or on time — not a violation
    else:
        return (day + 1) * horizon + a_i, True  # missed window → next day


# ── Shared evaluator ──────────────────────────────────────────────────────────
def evaluate(coords, tour, tw, svc, perturbs):
    """
    Total makespan with multi-day delivery support.

    Timing rules (clients only — depot is always open)
    ----------------------------------------------------------
    Arriving before window opens on any day → wait (NOT a violation).
    Arriving after window closes on that day → violation, jump to
    next-day opening  (t = (day+1)*H + a_i).

    Returns (makespan_normalised, violations_count).
    Multiply makespan by SCALE to get minutes.
    """
    horizon    = tw[0, 1].item()
    dist_mat   = torch.cdist(coords, coords)
    t          = 0.0
    violations = 0

    for k in range(len(tour)):
        i = tour[k]
        j = tour[(k + 1) % len(tour)]

        if k > 0:
            if i != 0:
                a_i = tw[i, 0].item()
                b_i = tw[i, 1].item()
                t, viol = _tw_advance(t, a_i, b_i, horizon)
                if viol:
                    violations += 1
            t += svc[i].item()

        base = dist_mat[i, j].item()
        mult = 1.0
        for pi, pj, ts, te, alpha in perturbs:
            if (pi == i and pj == j) or (pi == j and pj == i):
                if ts <= t <= te:
                    mult = max(mult, 1.0 + alpha)
        t += base * mult

    return t, violations


def tw_greedy_decode(p_hat, coords, tw, svc, perturbs):
    """
    TW-aware greedy decoding with multi-day support.

    A city is accepted if arrival does not exceed b_i + day*H
    (the window close on the day of arrival).
    Early arrivals (before a_i + day*H) are always accepted — truck waits.
    """
    n        = p_hat.shape[0]
    horizon  = tw[0, 1].item()
    dist_mat = torch.cdist(coords, coords)
    visited  = torch.zeros(n, dtype=torch.bool)
    tour     = [0]
    visited[0] = True
    t        = 0.0

    for _ in range(n - 1):
        cur       = tour[-1]
        unvisited = [j for j in range(n) if not visited[j]]

        def _arr(j):
            base = dist_mat[cur, j].item()
            mult = 1.0
            for pi, pj, ts, te, alpha in perturbs:
                if (pi == cur and pj == j) or (pi == j and pj == cur):
                    if ts <= t <= te:
                        mult = max(mult, 1.0 + alpha)
            return t + base * mult

        arr = {j: _arr(j) for j in unvisited}

        probs   = p_hat[cur]
        by_prob = sorted(unvisited, key=lambda j: probs[j].item(), reverse=True)

        # Accept if arrival does not miss the window on the arrival day.
        # Early arrival (before window opens) is fine — truck waits.
        chosen = None
        for j in by_prob:
            if j == 0:
                chosen = j; break
            t_arr = arr[j]
            day_j = int(t_arr / horizon) if horizon > 0 else 0
            if t_arr <= tw[j, 1].item() + day_j * horizon:
                chosen = j; break

        if chosen is None:
            def _wait_cost(j):
                t_arr = arr[j]
                day_j = int(t_arr / horizon) if horizon > 0 else 0
                a_day = tw[j, 0].item() + day_j * horizon
                b_day = tw[j, 1].item() + day_j * horizon
                if t_arr <= b_day:
                    return max(0.0, a_day - t_arr)
                else:
                    return tw[j, 0].item() + (day_j + 1) * horizon - t_arr
            chosen = min(unvisited, key=_wait_cost)

        tour.append(chosen)
        visited[chosen] = True

        t_arr = arr[chosen]
        if chosen != 0:
            t, _ = _tw_advance(t_arr, tw[chosen, 0].item(), tw[chosen, 1].item(), horizon)
        else:
            t = t_arr
        t += svc[chosen].item()

    return tour


def run_benchmark(inst, gnn_model, n_reps=N_REPS):
    coords   = inst['coords']
    tw       = inst['tw']
    svc      = inst['svc']
    perturbs = inst['perturbs']
    nf       = inst['nf'].to(DEVICE)
    ef       = inst['ef'].to(DEVICE)

    gnn_times = []
    with torch.no_grad():
        gnn_model(nf, ef)
        for _ in range(n_reps):
            if DEVICE.type == 'cuda':
                torch.cuda.synchronize()
            t0 = time.perf_counter()
            p_hat = gnn_model(nf, ef)
            if DEVICE.type == 'cuda':
                torch.cuda.synchronize()
            gnn_times.append(time.perf_counter() - t0)

    p_hat  = p_hat.cpu()
    p_sym  = (p_hat + p_hat.T) / 2
    t_gnn  = tw_greedy_decode(p_sym, coords, tw, svc, perturbs)
    makespan, viol = evaluate(coords, t_gnn, tw, svc, perturbs)

    return {
        'tour':       t_gnn,
        'makespan':   makespan * SCALE,
        'violations': viol,
        'ms':         float(np.mean(gnn_times)) * 1e3,
    }


def plot_tour(ax, coords, tour, tw, svc, perturbs, title='', max_label_n=50):
    xy       = coords.numpy()
    n        = len(tour)
    dist_mat = torch.cdist(coords, coords)
    horizon  = tw[0, 1].item()
    t        = 0.0
    arc_colors = []

    for k in range(n):
        i = tour[k]; j = tour[(k + 1) % n]
        if k > 0:
            if i != 0:
                t, _ = _tw_advance(t, tw[i, 0].item(), tw[i, 1].item(), horizon)
            t += svc[i].item()
        color = 'steelblue'; mult = 1.0
        for pi, pj, ts, te, alpha in perturbs:
            if (pi == i and pj == j) or (pi == j and pj == i):
                if ts <= t <= te:
                    color = 'red'; mult = max(mult, 1.0 + alpha)
        arc_colors.append(color)
        t += dist_mat[i, j].item() * mult

    for k in range(n):
        i = tour[k]; j = tour[(k + 1) % n]
        ax.annotate('', xy=(xy[j,0], xy[j,1]), xytext=(xy[i,0], xy[i,1]),
                    arrowprops=dict(arrowstyle='->', color=arc_colors[k], lw=1.8, alpha=0.85))

    ax.scatter(xy[:,0], xy[:,1], s=120, zorder=5, color='black')
    if n <= max_label_n:
        for idx, (xi, yi) in enumerate(xy):
            a_i = tw[idx, 0].item() * SCALE
            b_i = tw[idx, 1].item() * SCALE
            ax.annotate(f'{idx}\n[{a_i:.0f},{b_i:.0f}]',
                        (xi + 0.015, yi + 0.015), fontsize=8, color='#333333')
    ax.set_title(title, fontsize=10)
    ax.set_xlim(-0.05, 1.10); ax.set_ylim(-0.05, 1.10)
    ax.set_aspect('equal'); ax.grid(True, alpha=0.2)


def _simulate_arrivals(tour, coords, tw, svc, perturbs):
    horizon_n = tw[0, 1].item()
    horizon   = horizon_n * SCALE
    dist_mat  = torch.cdist(coords, coords)
    t         = 0.0      # normalised
    records   = []
    tour_full = list(tour) + [tour[0]]

    for k in range(len(tour_full)):
        i       = tour_full[k]
        raw_arr = t * SCALE

        if k > 0:
            if i != 0:
                t, _ = _tw_advance(t, tw[i, 0].item(), tw[i, 1].item(), horizon_n)
            t += svc[i].item()

        records.append((raw_arr, t * SCALE - svc[i].item() * SCALE, t * SCALE))

        if k < len(tour_full) - 1:
            j    = tour_full[k + 1]
            base = dist_mat[i, j].item()
            mult = 1.0
            for pi, pj, ts, te, alpha in perturbs:
                if (pi == i and pj == j) or (pi == j and pj == i):
                    if ts <= t <= te:
                        mult = max(mult, 1.0 + alpha)
            t += base * mult

    return records, tour_full


def _gantt(ax, tour, coords, tw, svc, perturbs, max_stops=40):
    horizon = tw[0, 1].item() * SCALE
    records, tour_ext = _simulate_arrivals(tour, coords, tw, svc, perturbs)
    show    = min(len(tour_ext), max_stops)
    max_t   = max(rec[0] for rec in records[:show]) if records else horizon

    for rank in range(show):
        city_idx = tour_ext[rank]
        is_depot = (city_idx == 0)
        a_i      = tw[city_idx, 0].item() * SCALE
        b_i      = tw[city_idx, 1].item() * SCALE
        raw_arr, eff_start, depart = records[rank]

        if is_depot:
            ax.barh(rank, max_t + horizon * 0.05, left=0, height=0.55,
                    color='#fffacc', edgecolor='goldenrod', linewidth=0.8, alpha=0.9)
        else:
            visit_day = int(eff_start / horizon)
            left = a_i + visit_day * horizon
            ax.barh(rank, b_i - a_i, left=left, height=0.55,
                    color='#d0eaff', edgecolor='steelblue', linewidth=0.8, alpha=0.85)

        svc_dur = depart - eff_start
        if svc_dur > 0:
            ax.barh(rank, svc_dur, left=eff_start, height=0.25, color='steelblue', alpha=0.55)

        # Multi-day aware arrival marker
        if is_depot:
            col, mk = 'goldenrod', 'D'
        else:
            day_raw = int(raw_arr / horizon) if horizon > 0 else 0
            b_day   = b_i + day_raw * horizon
            a_day   = a_i + day_raw * horizon
            if raw_arr > b_day:
                col, mk = 'tomato',     'v'   # true violation
            elif raw_arr < a_day:
                col, mk = 'darkorange', '>'   # early (waiting, not violation)
            else:
                col, mk = 'seagreen',   '^'   # on time

        ax.plot(raw_arr, rank, marker=mk, color=col, ms=6, zorder=5,
                markeredgecolor='white', markeredgewidth=0.4)

    n_days = int(max_t / horizon) + 2
    for d in range(1, n_days):
        ax.axvline(d * horizon, color='gray', lw=0.9, linestyle='--', alpha=0.4,
                   label='day boundary' if d == 1 else '')

    _perturb_colors = ['#ffaaaa', '#aaffaa', '#aaaaff', '#ffddaa', '#ddaaff']
    for idx, (pi, pj, ts, te, alpha) in enumerate(perturbs):
        ts_m = ts * SCALE; te_m = te * SCALE
        color = _perturb_colors[idx % len(_perturb_colors)]
        ax.axvspan(ts_m, te_m, alpha=0.18, color=color, zorder=0)
        mid = (ts_m + te_m) / 2
        ax.axvline(ts_m, color=color, lw=0.8, linestyle=':', alpha=0.6)
        ax.axvline(te_m, color=color, lw=0.8, linestyle=':', alpha=0.6)
        ax.text(mid, -0.6, f'arc({pi},{pj}) x{1+alpha:.2f}',
                ha='center', va='center', fontsize=6.5, color='darkred', fontweight='bold',
                bbox=dict(boxstyle='round,pad=0.15', fc='white', ec='none', alpha=0.7))

    ax.set_yticks(range(show))
    ax.set_yticklabels(
        [f'depot (step {k})' if tour_ext[k] == 0 else f'city {tour_ext[k]:>3d}  step {k}'
         for k in range(show)],
        fontsize=max(6, 9 - show // 10))
    ax.invert_yaxis()
    ax.set_xlabel('Time (minutes)')
    suffix = f' — first {show} of {len(tour_ext)} stops' if show < len(tour_ext) else ''
    ax.set_title(f'Gantt: time windows vs truck arrivals{suffix}')
    ax.grid(axis='x', alpha=0.2)

    from matplotlib.lines import Line2D
    from matplotlib.patches import Patch
    ax.legend(handles=[
        Patch(facecolor='#d0eaff', edgecolor='steelblue', label='time window [a, b]'),
        Patch(facecolor='steelblue', alpha=0.5, label='service time'),
        Line2D([0],[0], marker='^', color='seagreen',   lw=0, ms=7, label='on time'),
        Line2D([0],[0], marker='>', color='darkorange', lw=0, ms=7, label='early (waiting, not a violation)'),
        Line2D([0],[0], marker='v', color='tomato',     lw=0, ms=7, label='violation (missed window)'),
        Line2D([0],[0], marker='D', color='goldenrod',  lw=0, ms=7, label='depot (always open)'),
        Line2D([0],[0], color='gray', lw=0.9, linestyle='--', label='day boundary'),
        Patch(facecolor='#ffaaaa', alpha=0.4, label='perturbation active period'),
    ], fontsize=7, loc='lower right')


def show_results(n, result, inst):
    r       = result
    horizon = inst['tw'][0, 1].item() * SCALE
    days    = max(1, round(r['makespan'] / horizon))

    print(f'\n── GNN  n = {n} ────────────────────────────────────────────────')
    print(f"  makespan  : {r['makespan']:>10.2f} min  (~{days} day(s) @ {horizon:.0f} min/day)")
    print(f"  violations: {r['violations']:>10d}  (cities where window was missed)")
    print(f"  inference : {r['ms']:>10.3f} ms")

    gantt_rows = min(n, 50)
    row_height = max(0.22 * gantt_rows, 3)
    fig = plt.figure(figsize=(16, 6 + row_height))
    gs  = fig.add_gridspec(2, 2, height_ratios=[1, row_height / 6], hspace=0.35, wspace=0.3)

    ax_bar  = fig.add_subplot(gs[0, 0])
    ax_map  = fig.add_subplot(gs[0, 1])
    ax_gant = fig.add_subplot(gs[1, :])

    fig.suptitle(
        f"TSPTW-D GNN — n = {n}  |  makespan = {r['makespan']:.0f} min"
        f"  violations = {r['violations']}  (~{days}d)",
        fontsize=12, y=0.98)

    ax_bar.barh(['makespan'], [r['makespan']], color='steelblue', height=0.4)
    for d in range(1, days + 1):
        ax_bar.axvline(d * horizon, color='tomato', lw=1.1, linestyle='--', alpha=0.7,
                       label='day boundary' if d == 1 else '')
    ax_bar.set_xlabel('minutes')
    ax_bar.set_title(f'Total makespan  ({days} day(s))')
    ax_bar.legend(fontsize=8)
    ax_bar.grid(axis='x', alpha=0.3)
    ax_bar.text(r['makespan'] / 2, 0, f"{r['makespan']:.0f} min",
                ha='center', va='center', color='white', fontweight='bold', fontsize=10)

    max_label_n = 30 if n <= 30 else 0
    plot_tour(ax_map, inst['coords'], r['tour'], inst['tw'], inst['svc'], inst['perturbs'],
              title=f"GNN route  violations={r['violations']}", max_label_n=max_label_n)

    _gantt(ax_gant, result['tour'], inst['coords'], inst['tw'], inst['svc'], inst['perturbs'],
           max_stops=gantt_rows)

    plt.savefig(FIGURES_DIR / f'benchmark_n{n}.png', dpi=130, bbox_inches='tight')
    plt.show()
    print(f'Saved: benchmark_n{n}.png')

# %% [markdown]
# ### n = 10 cities

# %%
inst_10   = load_dataset(10)
result_10 = run_benchmark(inst_10, model)
show_results(10, result_10, inst_10)

# %% [markdown]
# ### n = 100 cities

# %%
inst_100   = load_dataset(100)
result_100 = run_benchmark(inst_100, model)
show_results(100, result_100, inst_100)

# %% [markdown]
# ### All datasets

# %%
# ── All available datasets (capped at n≤500 for CPU feasibility) ─────────────
all_results = {}
for n_ds, path in discover_datasets(max_n=500):
    print(f'Running n={n_ds} ...')
    inst = load_dataset(n_ds)
    res  = run_benchmark(inst, model, n_reps=1)
    all_results[n_ds] = res
    horizon = inst['tw'][0, 1].item() * SCALE
    days    = max(1, round(res['makespan'] / horizon))
    print(f'  makespan={res["makespan"]:.1f} min (~{days}d)  violations={res["violations"]}  {res["ms"]:.2f} ms')

print('\n── Summary ─────────────────────────────────────────────────────────────')
print(f'{"n":>8}  {"makespan (min)":>14}  {"days":>6}  {"viol":>6}  {"ms":>10}')
print('-' * 52)
for n_ds, res in sorted(all_results.items()):
    horizon = load_dataset(n_ds)['tw'][0, 1].item() * SCALE
    days    = max(1, round(res['makespan'] / horizon))
    print(f'{n_ds:>8}  {res["makespan"]:>14.1f}  {days:>6}  {res["violations"]:>6}  {res["ms"]:>10.3f}')

# %%
import pandas as pd

_results_dir = Path(_HERE) / '..' / '..' / 'results'
_results_dir.mkdir(exist_ok=True)

rows = []
for n_ds, res in sorted(all_results.items()):
    rows.append({
        'algo':     'gnn',
        'n':        n_ds,
        'run':      0,
        'makespan': round(res['makespan'], 2),
        'time_ms':  round(res['ms'], 1),
        'feasible': res['violations'] == 0,
    })

df_gnn = pd.DataFrame(rows)
out_path = _results_dir / 'gnn_results.csv'
df_gnn.to_csv(out_path, index=False)
print(df_gnn.to_string(index=False))
print(f'\nSaved → {out_path.resolve()}')

# %% [markdown]
# ## 4. Step-by-step GNN Decode Visualisation
#
# For a chosen instance, replay the GNN's greedy decoding **round by round**.
#
# Each panel shows one decision step:
# - **★ (yellow star)** — current node the GNN is deciding *from*
# - **◆ (green diamond)** — the node the GNN *chose* to visit next
# - **Node colour** — GNN edge score from the current node (green = high, red = low)
# - **Grey nodes** — already visited
# - **Blue arrow** — normal arc; **Red arrow** — arc traversed during an active perturbation
# - Title shows the top-3 candidate scores, the simulated arrival time, and whether the chosen node is within its time window.

# %%
import matplotlib.cm as _cm
from matplotlib.colors import Normalize as _Norm
from matplotlib.cm import ScalarMappable as _SM


def visualize_gnn_rounds(inst, gnn_model, max_rounds=None, cols=4, figsize_per_cell=4.2):
    """
    Replay the GNN greedy decode step by step and display each decision round.

    Parameters
    ----------
    inst        : benchmark instance dict (from load_dataset)
    gnn_model   : trained TSPGNN
    max_rounds  : cap on the number of rounds shown (None = all)
    cols        : subplot columns in the grid
    figsize_per_cell : inches per subplot side
    """
    coords   = inst['coords']
    tw       = inst['tw']
    svc      = inst['svc']
    perturbs = inst['perturbs']
    nf       = inst['nf'].to(DEVICE)
    ef       = inst['ef'].to(DEVICE)
    n        = coords.shape[0]
    xy       = coords.numpy()
    dist_mat = torch.cdist(coords, coords)
    horizon  = tw[0, 1].item()

    # ── GNN forward pass ──────────────────────────────────────────────────────
    with torch.no_grad():
        p_hat = gnn_model(nf, ef).cpu()  # (n, n) edge probabilities

    # ── Replay greedy_decode, recording each decision ─────────────────────────
    steps   = []
    visited = torch.zeros(n, dtype=torch.bool)
    tour    = [0]
    visited[0] = True
    t = 0.0   # simulated arrival time (matches evaluate() logic)

    for step_idx in range(n - 1):
        cur = tour[-1]

        # Advance time: multi-day TW wait + service at cur
        if step_idx > 0:
            a_i = tw[cur, 0].item()
            b_i = tw[cur, 1].item()
            t, _ = _tw_advance(t, a_i, b_i, horizon)
            t += svc[cur].item()

        # Scores from current node, masked for visited
        scores = p_hat[cur].clone()
        scores_masked = scores.masked_fill(visited, float('-inf'))

        # Ranked candidates
        unvisited_ranked = sorted(
            [(j, scores[j].item()) for j in range(n) if not visited[j]],
            key=lambda x: -x[1]
        )
        chosen = unvisited_ranked[0][0]

        # Travel to chosen node (with perturbation check)
        base = dist_mat[cur, chosen].item()
        mult = 1.0
        for pi, pj, ts, te, alpha in perturbs:
            if (pi == cur and pj == chosen) or (pi == chosen and pj == cur):
                if ts <= t <= te:
                    mult = max(mult, 1.0 + alpha)
        t_arrive = t + base * mult

        # TW status of chosen node — multi-day aware
        a_c   = tw[chosen, 0].item()
        b_c   = tw[chosen, 1].item()
        day_c = int(t_arrive / horizon) if horizon > 0 else 0
        a_day = a_c + day_c * horizon
        b_day = b_c + day_c * horizon
        if t_arrive > b_day:
            tw_status = 'NEXT-DAY'
        elif t_arrive < a_day:
            tw_status = 'early (waits)'
        else:
            tw_status = 'in window'

        steps.append({
            'round':         step_idx + 1,
            'from':          cur,
            'chosen':        chosen,
            'chosen_score':  unvisited_ranked[0][1],
            'top3':          unvisited_ranked[:3],
            'runner_up_gap': (unvisited_ranked[0][1] - unvisited_ranked[1][1])
                             if len(unvisited_ranked) > 1 else 0.0,
            'scores':        scores.numpy().copy(),
            'visited_snap':  visited.clone().numpy(),
            'tour_snap':     list(tour),
            't_depart':      t,
            't_arrive':      t_arrive,
            'perturbed':     mult > 1.0,
            'tw_status':     tw_status,
        })

        tour.append(chosen)
        visited[chosen] = True
        t = t_arrive

    # ── Cap rounds ────────────────────────────────────────────────────────────
    if max_rounds is not None:
        steps = steps[:max_rounds]
    n_steps = len(steps)

    # ── Consistent colour scale across all rounds ─────────────────────────────
    all_sc  = [s['scores'] for s in steps]
    vmin    = float(min(sc.min() for sc in all_sc))
    vmax    = float(max(sc.max() for sc in all_sc))
    norm    = _Norm(vmin=vmin, vmax=vmax)
    cmap    = _cm.RdYlGn

    # ── Build grid ────────────────────────────────────────────────────────────
    ncols  = min(cols, n_steps)
    nrows  = (n_steps + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols,
                             figsize=(figsize_per_cell * ncols,
                                      figsize_per_cell * nrows))
    axes_flat = np.array(axes).flatten() if n_steps > 1 else [axes]

    for ax, step in zip(axes_flat, steps):
        vis   = step['visited_snap']
        cur   = step['from']
        chsn  = step['chosen']
        sc    = step['scores']
        tsf   = step['tour_snap']

        # ── Draw existing tour (grey arrows) ─────────────────────────────────
        for k in range(len(tsf) - 1):
            i, j = tsf[k], tsf[k + 1]
            ax.annotate('', xy=(xy[j, 0], xy[j, 1]), xytext=(xy[i, 0], xy[i, 1]),
                        arrowprops=dict(arrowstyle='->', color='dimgray',
                                        lw=1.3, alpha=0.6))

        # ── New chosen arc (blue or red for perturbed) ────────────────────────
        arc_col = 'crimson' if step['perturbed'] else 'steelblue'
        ax.annotate('', xy=(xy[chsn, 0], xy[chsn, 1]),
                    xytext=(xy[cur, 0], xy[cur, 1]),
                    arrowprops=dict(arrowstyle='->', color=arc_col,
                                    lw=2.4, alpha=0.95))

        # ── Unvisited nodes — colour by GNN score ─────────────────────────────
        for j in range(n):
            if not vis[j]:
                col = cmap(norm(sc[j]))
                ax.scatter(xy[j, 0], xy[j, 1], s=170, color=col, zorder=4,
                           edgecolors='black', linewidths=0.7)

        # ── Visited nodes (grey) ──────────────────────────────────────────────
        for j in range(n):
            if vis[j] and j != cur:
                ax.scatter(xy[j, 0], xy[j, 1], s=120, color='#cccccc', zorder=4,
                           edgecolors='#888888', linewidths=0.7)

        # ── Current node (yellow star) ────────────────────────────────────────
        ax.scatter(xy[cur, 0], xy[cur, 1], s=280, color='gold', zorder=6,
                   marker='*', edgecolors='darkorange', linewidths=1.3)

        # ── Chosen node (green diamond) ───────────────────────────────────────
        ax.scatter(xy[chsn, 0], xy[chsn, 1], s=320, color='limegreen', zorder=5,
                   marker='D', edgecolors='darkgreen', linewidths=1.5, alpha=0.85)

        # ── Node ID labels (small instances only) ────────────────────────────
        if n <= 25:
            for j in range(n):
                ax.annotate(str(j), (xy[j, 0] + 0.022, xy[j, 1] + 0.022),
                            fontsize=7, zorder=7)

        # ── Per-round title with decision rationale ────────────────────────────
        top3_str = '  |  '.join(
            f'node {nj}: {sv:.3f}' for nj, sv in step['top3']
        )
        gap_str  = f'  (Δ={step["runner_up_gap"]:+.3f} vs runner-up)'
        perturb_str = '  ⚠ PERTURBED ARC' if step['perturbed'] else ''
        title = (
            f"Round {step['round']}:  node {cur} → node {chsn}"
            f"  (score {step['chosen_score']:.3f}){gap_str}"
            f"Top-3: {top3_str}"
            f"t_arrive={step['t_arrive']:.3f}  [{step['tw_status']}]"
            f"{perturb_str}"
        )
        ax.set_title(title, fontsize=7.0, loc='center', pad=4)
        ax.set_xlim(-0.05, 1.10); ax.set_ylim(-0.05, 1.10)
        ax.set_aspect('equal'); ax.grid(True, alpha=0.15)
        ax.tick_params(left=False, bottom=False,
                       labelleft=False, labelbottom=False)

    for ax in axes_flat[n_steps:]:
        ax.set_visible(False)

    # ── Shared colour-bar ─────────────────────────────────────────────────────
    sm = _SM(cmap=cmap, norm=norm)
    sm.set_array([])
    fig.colorbar(sm, ax=list(axes_flat[:n_steps]), shrink=0.55, pad=0.02,
                 label='GNN edge score from current node')

    fig.suptitle(
        f'GNN Greedy Decode — Round by Round  (n={n}  |  device: {DEVICE})'
        '★ current node   ◆ chosen next   colour = GNN score   '
        'grey = visited   red arc = perturbed',
        fontsize=10, y=1.01
    )
    plt.tight_layout()
    plt.show()
    print(f'Final tour: {tour}')


print('visualize_gnn_rounds() loaded.')

# %%
# ── Step-by-step decode for the n=10 instance ────────────────────────────────
# max_rounds=None  → show all n-1 steps
# For larger n, use max_rounds=15 (or similar) to keep the figure manageable.
visualize_gnn_rounds(inst_10, model, max_rounds=None, cols=3)

# %%
# ── Larger instances: show the first 12 rounds ───────────────────────────────
# Uncomment whichever dataset you want to inspect.

# visualize_gnn_rounds(inst_50,  model, max_rounds=12, cols=4)
# visualize_gnn_rounds(inst_100, model, max_rounds=12, cols=4)
# visualize_gnn_rounds(inst_200, model, max_rounds=12, cols=4)
